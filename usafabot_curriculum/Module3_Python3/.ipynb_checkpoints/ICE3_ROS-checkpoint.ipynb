# %% [markdown]
# # Module 3: Python3 for Robotics
# ## In-Class Exercise 3 - ROS
# Below you will run ROS commands. The "!" character in the front allows us to run bash commands from Jupter and would **NOT** be used in the command line.
#
# With the client and server nodes running execute the below commands.

# %% [markdown]
# List the active topics:

# %%
!

# %% [markdown]
# Display running nodes and communication between them:

# %%
!

# %% [markdown]
# Exit the rqt_graph and then list all running nodes:

# %%
!

# %% [markdown]
# Show information about a the 'client' topic such as what type of messages are sent over the topic and publishing and subscribing nodes.

# %%
!

# %% [markdown]
# Display information about the message that is sent over the client topic.

# %%
!

# %% [markdown]
# Display messages sent over the client topic:

# %%
!

# %% [markdown]
# In the ICE3_Client notebook reset the Jupter kernel and clear output: At the top menu bar select "Kernel" and "Restart & Clear Output" (you do not need to restart the server). Make sure to rerun the code blocks to import modules, build the class, and create the main. When you send a message you should see the message echoed above.

# %% [markdown]
# ## Cleanup
# In each of the notebooks reset the Jupter kernel and clear output. Close each notebook. Shutdown the notebook server by typing `ctrl+c` within the terminal you ran `Jupter-notebook` in. Select 'y'.
